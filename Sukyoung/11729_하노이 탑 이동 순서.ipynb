# %%
def hanoi(n):
    result=[]
    if n == 1:
        result.append([1,3])
        return result
    else:
        f(n) = f(n-1)
# Out:
#   Input In [2]
#     if n < 1:
#              ^
# IndentationError: expected an indented block
